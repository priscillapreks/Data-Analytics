# %% [markdown]
# ### **Stack Overflow Insights**
#
#
# Cerca de 65 mil desenvolvedores, de  de 180 países, participaram da pesquisa anual do Stack Overflow. O **2020 Annual Developer Survey** avalia todos os aspectos da experiência de um desenvolvedor, desde a eduação até a busca de emprego e satisfação na carreira.
#
# Fonte dos dados: [Stack Overflow Insights](https://insights.stackoverflow.com/survey)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import textwrap
from scipy import stats
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# importa os dados para o colab
from google.colab import files
#uploaded = files.upload()

# %%
data = pd.read_csv('survey_results_public.csv', index_col='Respondent', na_values = ['no info', '.', 'NA', 'Missing'])
questions = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
# dicionário 
questions.head()
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...
# Hobbyist                              Do you code as a hobby?
# Age         What is your age (in years)? If you prefer not...
# Age1stCode  At what age did you write your first line of c...

# %%
# visualizando os dados
data.head(3)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
# 3              I code primarily as a hobby      Yes  NaN         15      NaN
#
#             CompTotal  ConvertedComp             Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN             Germany   European Euro
# 2                 NaN            NaN      United Kingdom  Pound sterling
# 3                 NaN            NaN  Russian Federation             NaN
#
#            CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
# 3                     NaN                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
# 3                                                 NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
# 3                                                         NaN
#
#                                                     EdLevel  \
# Respondent
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                       NaN
#
#                                                    Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Employed full-time
# 3                                                         NaN
#
#                                Ethnicity Gender  \
# Respondent
# 1           White or of European descent    Man
# 2                                    NaN    NaN
# 3                                    NaN    NaN
#
#                                                    JobFactors  \
# Respondent
# 1           Languages, frameworks, and other technologies ...
# 2                                                         NaN
# 3                                                         NaN
#
#                         JobSat                                       JobSeek  \
# Respondent
# 1           Slightly satisfied  I am not interested in new job opportunities
# 2            Very dissatisfied  I am not interested in new job opportunities
# 3                          NaN                                           NaN
#
#               LanguageDesireNextYear        LanguageWorkedWith  \
# Respondent
# 1             C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript
# 2                       Python;Swift          JavaScript;Swift
# 3           Objective-C;Python;Swift  Objective-C;Python;Swift
#
#                       MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
#
#                                 NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 1           Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 2                    Confluence;Jira;Github;Gitlab;Slack       NaN
# 3                                                    NaN       NaN
#
#                  NEWDevOpsImpt         NEWEdImpt NEWJobHunt  \
# Respondent
# 1           Somewhat important  Fairly important        NaN
# 2                          NaN  Fairly important        NaN
# 3                          NaN               NaN        NaN
#
#            NEWJobHuntResearch       NEWLearn NEWOffTopic NEWOnboardGood  \
# Respondent
# 1                         NaN    Once a year    Not sure            NaN
# 2                         NaN    Once a year    Not sure            NaN
# 3                         NaN  Once a decade         NaN            NaN
#
#            NEWOtherComms                       NEWOvertime  \
# Respondent
# 1                     No  Often: 1-2 days per week or more
# 2                     No                               NaN
# 3                     No                               NaN
#
#                                           NEWPurchaseResearch NEWPurpleLink  \
# Respondent
# 1           Start a free trial;Ask developers I know/work ...        Amused
# 2                                                         NaN        Amused
# 3                                                         NaN           NaN
#
#                                                    NEWSOSites  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
#
#                              OrgSize  \
# Respondent
# 1                   2 to 9 employees
# 2           1,000 to 4,999 employees
# 3                                NaN
#
#                                     PlatformDesireNextYear PlatformWorkedWith  \
# Respondent
# 1           Android;iOS;Kubernetes;Microsoft Azure;Windows            Windows
# 2                               iOS;Kubernetes;Linux;MacOS                iOS
# 3                                                      NaN                NaN
#
#                              PurchaseWhat                Sexuality SOAccount  \
# Respondent
# 1                                     NaN  Straight / Heterosexual        No
# 2           I have little or no influence                      NaN       Yes
# 3                                     NaN                      NaN       Yes
#
#                      SOComm                           SOPartFreq  \
# Respondent
# 1            No, not at all                                  NaN
# 2           Yes, definitely  Less than once per month or monthly
# 3             Yes, somewhat      A few times per month or weekly
#
#                        SOVisitFreq                  SurveyEase  \
# Respondent
# 1           Multiple times per day  Neither easy nor difficult
# 2           Multiple times per day                         NaN
# 3            Daily or almost daily  Neither easy nor difficult
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
# 3           Appropriate in length   NaN
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
# 3                                                         NaN
#
#            WebframeDesireNextYear    WebframeWorkedWith  \
# Respondent
# 1                    ASP.NET Core  ASP.NET;ASP.NET Core
# 2                             NaN                   NaN
# 3                             NaN                   NaN
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 1            Just as welcome now as I felt last year         50.0        36
# 2           Somewhat more welcome now than last year          NaN         7
# 3           Somewhat more welcome now than last year          NaN         4
#
#            YearsCodePro
# Respondent
# 1                    27
# 2                     4
# 3                   NaN

# %%
# todas as colunas do df
print(data.columns.values)
# Out:
# ['MainBranch' 'Hobbyist' 'Age' 'Age1stCode' 'CompFreq' 'CompTotal'
#  'ConvertedComp' 'Country' 'CurrencyDesc' 'CurrencySymbol'
#  'DatabaseDesireNextYear' 'DatabaseWorkedWith' 'DevType' 'EdLevel'
#  'Employment' 'Ethnicity' 'Gender' 'JobFactors' 'JobSat' 'JobSeek'
#  'LanguageDesireNextYear' 'LanguageWorkedWith' 'MiscTechDesireNextYear'
#  'MiscTechWorkedWith' 'NEWCollabToolsDesireNextYear'
#  'NEWCollabToolsWorkedWith' 'NEWDevOps' 'NEWDevOpsImpt' 'NEWEdImpt'
#  'NEWJobHunt' 'NEWJobHuntResearch' 'NEWLearn' 'NEWOffTopic'
#  'NEWOnboardGood' 'NEWOtherComms' 'NEWOvertime' 'NEWPurchaseResearch'
#  'NEWPurpleLink' 'NEWSOSites' 'NEWStuck' 'OpSys' 'OrgSize'
#  'PlatformDesireNextYear' 'PlatformWorkedWith' 'PurchaseWhat' 'Sexuality'
#  'SOAccount' 'SOComm' 'SOPartFreq' 'SOVisitFreq' 'SurveyEase'
#  'SurveyLength' 'Trans' 'UndergradMajor' 'WebframeDesireNextYear'
#  'WebframeWorkedWith' 'WelcomeChange' 'WorkWeekHrs' 'YearsCode'
#  'YearsCodePro']

# %%
# selecionando as features
data = data[['MainBranch', 'Age', 'ConvertedComp', 'Country', 'DevType', 'EdLevel', 'Employment', 'Gender', 'JobFactors', 'JobSat', 
            'LanguageDesireNextYear', 'LanguageWorkedWith', 'MiscTechDesireNextYear', 'MiscTechWorkedWith', 'PlatformDesireNextYear', 'PlatformWorkedWith', 
            'UndergradMajor', 'WebframeDesireNextYear', 'WebframeWorkedWith', 'WorkWeekHrs', 'YearsCodePro']]

# %%
# renomeando a coluna ConvertedComp
data.rename(columns={'ConvertedComp': 'AnnualSalaryUSD'}, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64461 entries, 1 to 65112
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              64162 non-null  object
#  1   Age                     45446 non-null  float64
#  2   AnnualSalaryUSD         34756 non-null  float64
#  3   Country                 64072 non-null  object
#  4   DevType                 49370 non-null  object
#  5   EdLevel                 57431 non-null  object
#  6   Employment              63854 non-null  object
#  7   Gender                  50557 non-null  object
#  8   JobFactors              49349 non-null  object
#  9   JobSat                  45194 non-null  object
#  10  LanguageDesireNextYear  54113 non-null  object
#  11  LanguageWorkedWith      57378 non-null  object
#  12  MiscTechDesireNextYear  42379 non-null  object
#  13  MiscTechWorkedWith      40314 non-null  object
#  14  PlatformDesireNextYear  50605 non-null  object
#  15  PlatformWorkedWith      53843 non-null  object
#  16  UndergradMajor          50995 non-null  object
#  17  WebframeDesireNextYear  40024 non-null  object
#  18  WebframeWorkedWith      42279 non-null  object
#  19  WorkWeekHrs             41151 non-null  float64
#  20  YearsCodePro            46349 non-null  object
# dtypes: float64(3), object(18)
# memory usage: 10.8+ MB

# %%
# substitui por valores numéricos
data['YearsCodePro'].replace({'Less than 1 year': 0, 'More than 50 years': 51}, inplace=True)
data.dropna(subset=['YearsCodePro'], inplace=True)
data['YearsCodePro'] = data['YearsCodePro'].astype(int)

# %%
# estatísticas do df
data.describe()
# Out:
#                 Age  AnnualSalaryUSD   WorkWeekHrs  YearsCodePro
# count  36852.000000     3.462100e+04  40922.000000  46349.000000
# mean      32.269242     1.037684e+05     40.788262      8.491812
# std        8.855902     2.266323e+05     17.845422      7.905296
# min        1.000000     0.000000e+00      1.000000      0.000000
# 25%       26.000000     2.466000e+04     40.000000      3.000000
# 50%       30.000000     5.404900e+04     40.000000      6.000000
# 75%       37.000000     9.500000e+04     44.000000     12.000000
# max      279.000000     2.000000e+06    475.000000     51.000000

# %% [markdown]
# As colunas *Age* e *WorkWeekHrs* têm números impossiveis (outliers).
# Vamos corrigir esses dados limitando a valores mais aceitáveis:

# %%
# limitando a idade entre 14 e 99 anos 
data = data.query("Age >= 14 & Age < 100")

# %%
# limitando ao máximo de horas em uma semana 
data = data[(data['WorkWeekHrs'] < 168)]

# %%
data.isnull().sum()
# Out:
# MainBranch                   0
# Age                          0
# AnnualSalaryUSD           5038
# Country                      0
# DevType                    402
# EdLevel                    569
# Employment                  54
# Gender                     397
# JobFactors                 807
# JobSat                      50
# LanguageDesireNextYear    1822
# LanguageWorkedWith         192
# MiscTechDesireNextYear    8099
# MiscTechWorkedWith        9355
# PlatformDesireNextYear    3394
# PlatformWorkedWith        1656
# UndergradMajor            2567
# WebframeDesireNextYear    9466
# WebframeWorkedWith        7762
# WorkWeekHrs                  0
# YearsCodePro                 0
# dtype: int64

# %%
data.shape
# Out:
# (34961, 21)

# %% [markdown]
# ### **Data Viz**
#
# O objetivo desta análise é obter insights sobre a **carreira de tecnologia**. Portanto, vamos selecionar apenas devs que atuam profissionalmente na área:

# %%
# filtrando os devs profissionais
data = data[data['MainBranch'] == 'I am a developer by profession']

# %%
data.shape
# Out:
# (31720, 21)

# %% [markdown]
# **País de Origem**

# %%
# top 20 países
country_count  = data['Country'].value_counts(normalize=True)
country_count = country_count[:20,]

plt.figure(figsize=(16, 10))
sns.barplot( country_count.values, country_count.index, palette="rocket")
plt.title(questions.loc['Country', 'QuestionText'] + '  (TOP 20)')
plt.show()

print('\nTotal de países: ', data['Country'].nunique())
# Out:
# Total de países:  153

# %% [markdown]
# **Gênero**

# %%
gender = data['Gender'].value_counts(normalize=True)

plt.figure(figsize=(16, 5))
sns.barplot( gender.values, gender.index, palette="rocket")
plt.title(questions.loc['Gender', 'QuestionText'])
plt.show()

# %% [markdown]
# **Idade**

# %%
plt.figure(figsize=(22, 6))
sns.distplot(data['Age'], color="k")
plt.title(questions.loc['Age', 'QuestionText'])
plt.show()

# %% [markdown]
# **Educação**

# %%
edlevel = data['EdLevel'].value_counts(normalize=True)

plt.figure(figsize=(14, 6))
sns.barplot(edlevel.values, edlevel.index, palette='rocket')
plt.title(questions.loc['EdLevel', 'QuestionText'])
plt.show()

# %%
major = data['UndergradMajor'].value_counts(normalize=True)

plt.figure(figsize=(16, 8))
sns.barplot(major.values, major.index, palette='rocket')
plt.title(questions.loc['UndergradMajor', 'QuestionText'])
plt.show()

# %% [markdown]
# **Tempo de Experiência Profissional com Programação**

# %%
# cria age groups
bins=[1,5,10,15,20,25,30,35,40,45,50]
age_group = data.groupby(pd.cut(data['YearsCodePro'], bins=bins)).size()

# cria o gráfico
plt.figure(figsize=(16, 6))
sns.barplot(age_group.index, age_group.values, palette="rocket")
plt.title(questions.loc['YearsCodePro', 'QuestionText'])

plt.show()

# %% [markdown]
# **Área de atuação**

# %%
def split_and_plot(feature):
  '''Funcao para fazer o split das respostas e plotar o gráfico
  para questões tipo "marque todas que se aplicam" '''

  df = pd.DataFrame(data[feature].str.get_dummies(';').sum())
  df.reset_index(inplace=True)
  df.columns = [feature, 'Total']
  df = df.sort_values('Total', ascending=False)
  
  plt.figure(figsize=(20, 8))
  sns.barplot(x=feature, y='Total', data=df, palette="rocket")
  plt.title(textwrap.fill(questions.loc[feature, 'QuestionText'], width=100))
  plt.xticks(rotation=45, horizontalalignment='right')

# %%
split_and_plot('DevType')

# %% [markdown]
# #### **Linguagens & Tecnologia**

# %% [markdown]
# **Linguagens de Programação mais utilizadas**

# %%
split_and_plot('LanguageWorkedWith')

# %% [markdown]
# **Linguagens de programação que deseja utilizar no próximo ano**

# %%
split_and_plot('LanguageDesireNextYear')

# %% [markdown]
# **Web frameworks mais utilizados**

# %%
split_and_plot('WebframeDesireNextYear')

# %% [markdown]
# **Web frameworks que deseja utilizar no próximo ano**

# %%
split_and_plot('WebframeWorkedWith')

# %% [markdown]
# **Tecnologias mais utilizadas**

# %%
split_and_plot('MiscTechWorkedWith')

# %% [markdown]
# **Tecnologias que deseja utilizar no próximo ano**

# %%
split_and_plot('MiscTechDesireNextYear')

# %% [markdown]
# #### **Salários**

# %%
salary = data.loc[:, ['Country', 'DevType', 'Age', 'YearsCodePro', 'Employment', 'WorkWeekHrs', 'AnnualSalaryUSD', 'JobSat']]
salary.replace(0, np.nan, inplace=True)
salary.dropna(inplace=True)
salary.head()
# Out:
#                    Country                                            DevType  \
# Respondent
# 8            United States  Developer, back-end;Developer, desktop or ente...
# 10          United Kingdom  Database administrator;Developer, full-stack;D...
# 11          United Kingdom  Developer, back-end;Developer, desktop or ente...
# 12                   Spain                      Designer;Developer, front-end
# 14           United States  Developer, desktop or enterprise applications;...
#
#              Age  YearsCodePro          Employment  WorkWeekHrs  \
# Respondent
# 8           36.0          13.0  Employed full-time         39.0
# 10          22.0           4.0  Employed full-time         36.0
# 11          23.0           2.0  Employed full-time         40.0
# 12          49.0           7.0  Employed full-time         40.0
# 14          27.0           1.0  Employed full-time         40.0
#
#             AnnualSalaryUSD                 JobSat
# Respondent
# 8                  116000.0  Slightly dissatisfied
# 10                  32315.0         Very satisfied
# 11                  40070.0  Slightly dissatisfied
# 12                  14268.0      Very dissatisfied
# 14                  66000.0     Slightly satisfied

# %% [markdown]
# Sabemos que salários acima ou abaixo da média do mercado existem, então vamos tratar outliers apenas removendo os valores mais extremos:

# %%
print('Salários menores que: USD', data['AnnualSalaryUSD'].quantile(0.05)) # 5% menores salários
print('Salários maiores que: USD', data['AnnualSalaryUSD'].quantile(0.95)) # 5% maiores salários
# Out:
# Salários menores que: USD 5773.800000000001
# Salários maiores que: USD 250000.0

# %%
# removendo outliers
salary = data.query("AnnualSalaryUSD >= 5773 & AnnualSalaryUSD <= 250000")

# %% [markdown]
# **Salários x Tempo de experiência**

# %%
sns.set(style="darkgrid")
sns.jointplot("YearsCodePro","AnnualSalaryUSD", data=salary,
                  kind="reg", truncate=False,
                  color="m", height=8)

# %% [markdown]
# **Comparação por Países**

# %% [markdown]
# Para que a comparação salarial esteja mais próxima do real, vamos comparar os desenvolvedores empregados com a mesma carga horária:
#
# * Área de atuação: desenvolvimento (Developer)
# * Emprego: tempo integral
# * Carga-horária 40h/semana

# %%
# filtra por desenvolvedores 
salary_full = salary.loc[salary['DevType'].str.contains('Developer', na=False)]

# filtra devs empregados em tempo integral (40h/semana)
salary_full = salary.query("Employment == 'Employed full-time' and WorkWeekHrs == 40")

# %%
# Selecionando países para comparação
countries = ['United States', 'United Kingdom', 'India', 'Germany', 'Canada', 'Brazil']
filt = salary_full['Country'].isin(countries)
comp_countries = salary_full.loc[filt, ['Country', 'AnnualSalaryUSD']]

# cria o boxplot
plt.figure(figsize=(18, 8))
sns.boxplot(x='Country', y='AnnualSalaryUSD', data=comp_countries, palette='Set2')
plt.title('Salários anuais em US Dólares', fontsize=14)
plt.show()

print('____' * 50)
comp_countries.groupby('Country').describe()
# Out:
# ________________________________________________________________________________________________________________________________________________________________________________________________________
#                AnnualSalaryUSD                                                 \
#                          count           mean           std      min      25%
# Country
# Brazil                   449.0   24239.808463  18149.996216   5808.0  12876.0
# Canada                   476.0   73322.321429  29531.339049  18156.0  52942.0
# Germany                 1002.0   62158.971058  21808.433214   9080.0  48644.0
# India                    527.0   21627.349146  23406.134285   5794.0   9257.5
# United Kingdom           590.0   70649.513559  32118.075465  21328.0  46533.0
# United States           3066.0  111028.353229  42236.159776  10500.0  80000.0
#
#
#                      50%        75%       max
# Country
# Brazil           19512.0   29688.00  188016.0
# Canada           67784.0   86976.00  235970.0
# Germany          60535.0   73669.00  220000.0
# India            15358.0   24850.50  211104.0
# United Kingdom   64630.0   85940.25  232667.0
# United States   105000.0  135000.00  250000.0

# %% [markdown]
# -- Apesar dos EUA chamarem a atenção com a os salários mais altos, a variação entre o maior e menor salário é muito maior. O menor salário dos EUA, por exemplo, é mais baixo que os menores salários no Canadá e Reino Unido.
#
# -- Índia e Brasil têm menor variação salarial, mas a desvalorização do real e da rupia indiana frente ao dólar deixa as médias salariais muito abaixo na comparação com os demais países.

# %% [markdown]
# ####**Satisfação com o Trabalho**

# %%
job_sat = data['JobSat'].value_counts(normalize=True)

plt.figure(figsize=(16, 6))
sns.barplot(job_sat.values, job_sat.index, palette='GnBu_d')
plt.title(questions.loc['JobSat', 'QuestionText'], fontsize=14)
plt.show()

# %%
# cria um scatter plot com pontos de cores diferentes para o grau de satisfação
sns.set(style="whitegrid")
f, ax = plt.subplots(figsize=(14, 8))
sns.despine(f, left=True, bottom=True)
sat_ranking = ["Very satisfied", "Slightly satisfied", "Neither satisfied nor dissatisfied", "Slightly dissatisfied", "Very dissatisfied"]
sns.scatterplot(x="Age", y="AnnualSalaryUSD", hue="JobSat", palette="ch:r=-.2,d=.3_r", hue_order=sat_ranking, linewidth=0, data=salary, ax=ax)

# %% [markdown]
# Os diferentes graus de satisfação estão bem misturados no gráfico, o que indica que os devs com os maiores salários não necessariamente são os mais satisfeitos e vice-versa. Mas então, quais os outros fatores de trabalho importantes para os desenvolvedores?

# %% [markdown]
# **Fatores Importantes no Trabalho**
# Em uma situação com duas ofertas de emprego, na mesma região e com o mesmo salário e benefícios. Quais os fatores mais importantes para para a decisão?

# %%
# split e cria um df
job_factors = pd.DataFrame(data['JobFactors'].str.get_dummies(';').sum())
job_factors.reset_index(inplace=True)
job_factors.columns = ['JobFactors', 'Total']
job_factors = job_factors.sort_values('Total', ascending=False)

# cria o gráfico
plt.figure(figsize=(18, 8))
sns.barplot(x='Total', y='JobFactors', data=job_factors, palette="GnBu_d")
plt.title(textwrap.fill(questions.loc['JobFactors', 'QuestionText'], width=100), fontsize=14)
plt.yticks(fontsize=12)
plt.show()
